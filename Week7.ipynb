# %% [markdown]
# # Week 7 - Milestone One week

# %% [markdown]
# # 1. Lesson: no lesson this week.  Milestone One is due!

# %% [markdown]
# # 2. Weekly graph question

# %% [markdown]
# Below are the graphs from last week's weekly graph question.  Suppose you wanted to cause the viewer to examine the last three months of data first.  How could you use preattentive attributes to do that?  Suggest several possibilities.

# %%
import numpy as np
import seaborn as sns
import pandas as pd

# %%
numdates = 12
np.random.seed(0)
time_series = 100 * (np.random.normal(size = numdates) / 5 + np.arange(numdates) / 16)
datearray = pd.date_range(start='2023/01/01', end='2024/01/01', freq='ME')
ax = sns.lineplot(x = datearray, y = time_series)
ax.set_xlabel("Year and month")
ax.set_ylabel("Nitrate level (% of eutrophic value)")
# Out:
# Text(0, 0.5, 'Nitrate level (% of eutrophic value)')

# %%
np.random.seed(1)
time_series = 100 * (1 - (np.random.normal(size = numdates) / 8 + np.arange(numdates) / 16))
datearray = pd.date_range(start='2023/01/01', end='2024/01/01', freq='ME')
ax = sns.lineplot(x = datearray, y = time_series)
ax.set_xlabel("Year and month")
ax.set_ylabel("Phosphate level (% of eutrophic value)")
# Out:
# Text(0, 0.5, 'Phosphate level (% of eutrophic value)')

# %% [markdown]
# # 3. Working on your datasets
#
# This week, you can work on Milestone One rather than having a particular exercise about working on your datasets

# %% [markdown]
# # 4. Storytelling With Data plot
#
# Reproduce any graph of your choice in p. 99-119 of the Storytelling With Data book as best you can. (The first half of chapter four). You do not have to get the exact data values right, just the overall look and feel.

# %%
# Prepare
# Import dataset
df = pd.read_csv('cyber_events_database.csv', encoding='ISO-8859-1', dtype={'change_log': str})
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 16532 entries, 0 to 16531
# Data columns (total 46 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   slug                16532 non-null  str
#  1   original_method     16532 non-null  int64
#  2   event_date          16532 non-null  str
#  3   reported_date       1977 non-null   str
#  4   year                16532 non-null  int64
#  5   month               16532 non-null  int64
#  6   actor               16532 non-null  str
#  7   actor_type          16532 non-null  str
#  8   organization        16532 non-null  str
#  9   industry_code       16532 non-null  int64
#  10  industry            16532 non-null  str
#  11  motive              16532 non-null  str
#  12  event_type          16532 non-null  str
#  13  event_subtype       16532 non-null  str
#  14  magnitude           716 non-null    str
#  15  duration            692 non-null    str
#  16  scope               719 non-null    str
#  17  ip                  1414 non-null   str
#  18  org_data            1376 non-null   str
#  19  cust_data           1398 non-null   str
#  20  description         16531 non-null  str
#  21  source_url          16528 non-null  str
#  22  country             16532 non-null  str
#  23  country_iso3        15976 non-null  str
#  24  actor_country       16532 non-null  str
#  25  actor_country_iso3  16529 non-null  str
#  26  state               7874 non-null   str
#  27  county              7694 non-null   str
#  28  nato                16532 non-null  int64
#  29  eu                  16532 non-null  int64
#  30  shanghai_coop       16532 non-null  int64
#  31  oas                 16532 non-null  int64
#  32  mercosur            16532 non-null  int64
#  33  au                  16532 non-null  int64
#  34  ecowas              16532 non-null  int64
#  35  asean               16532 non-null  int64
#  36  opec                16532 non-null  int64
#  37  gulf_coop           16532 non-null  int64
#  38  g7                  16532 non-null  int64
#  39  g20                 16532 non-null  int64
#  40  aukus               16532 non-null  int64
#  41  csto                16532 non-null  int64
#  42  oecd                16532 non-null  int64
#  43  osce                16532 non-null  int64
#  44  five_eyes           16532 non-null  int64
#  45  change_log          16382 non-null  str
# dtypes: int64(21), str(25)
# memory usage: 5.8 MB

# %%
# Import
import matplotlib.pyplot as plt

# Filter for 'Nation-State' actor types
ns_df = df[df['actor_type'] == 'Nation-State']

# 2. Get the count of events per actor_country and take the top 20
top_20_actors = ns_df['actor_country'].value_counts().head(20)

# 3. Create the bar chart
plt.figure(figsize=(12, 6))
top_20_actors.plot(kind='bar', color='teal', edgecolor='black')

# Formatting the graph
plt.title('Top 20 Nation-State Actor Countries by Event Frequency', fontsize=14)
plt.xlabel('Actor Country', fontsize=12)
plt.ylabel('Number of Events', fontsize=12)
plt.xticks(rotation=45, ha='right')  # Rotates labels for readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()
